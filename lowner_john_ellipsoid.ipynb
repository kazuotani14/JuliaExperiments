# %% [markdown]
# # Convex optimization applications

# %% [markdown]
# ### Lowner-John Ellipsoid

# %% [markdown]
# Finds minimum volume ellipsoid around a finite set of points (2d in this case)
#
# An ellipse can be represented as $\{ v \text{ | } ||Av+b||_2 <= 1\}$
#
# Thus, the constraint to contain all points is: $||Ax_i + b ||_2 <= 1$ for all $x_i$
#
# We can minimize the volume of the ellipse by minimizing $log(det(inv(A)))$, because the volume of the ellipse is proportional to $det(inv(A))$. Intuition for this is that as values in A get larger, v must be smaller to keep $||Ax_i + b ||_2 <= 1$
#
# But we can't do $inv$ in Convex.jl so we instead _maximize_ $logdet(A)$. $logdet$ also adds an implicit constraint that A is symmetric positive-definite

# %% [markdown]
# First, we load the necessary libraries. Thig might take a while

# %%
using PyPlot
using Convex, SCS
set_default_solver(SCSSolver(verbose=0))
# Out:
# INFO: Precompiling module PyPlot.
# INFO: Precompiling module Convex.
#
# WARNING: deprecated syntax "abstract Vexity" at /home/kazu/.julia/v0.6/Convex/src/dcp.jl:21.
# Use "abstract type Vexity end" instead.
#
# WARNING: deprecated syntax "abstract Monotonicity" at /home/kazu/.julia/v0.6/Convex/src/dcp.jl:35.
# Use "abstract type Monotonicity end" instead.
#
# WARNING: deprecated syntax "abstract Sign" at /home/kazu/.julia/v0.6/Convex/src/dcp.jl:42.
# Use "abstract type Sign end" instead.
#
# WARNING: deprecated syntax "abstract AbstractExpr" at /home/kazu/.julia/v0.6/Convex/src/expressions.jl:41.
# Use "abstract type AbstractExpr end" instead.
#
# WARNING: deprecated syntax "abstract Constraint" at /home/kazu/.julia/v0.6/Convex/src/expressions.jl:42.
# Use "abstract type Constraint end" instead.
#
# WARNING: deprecated syntax "typealias Value Union{Number,AbstractArray}" at /home/kazu/.julia/v0.6/Convex/src/expressions.jl:103.
# Use "const Value = Union{Number,AbstractArray}" instead.
#
# WARNING: deprecated syntax "typealias ValueOrNothing Union{Value,Void}" at /home/kazu/.julia/v0.6/Convex/src/expressions.jl:104.
# Use "const ValueOrNothing = Union{Value,Void}" instead.
#
# WARNING: deprecated syntax "typealias AbstractExprOrValue Union{AbstractExpr,Value}" at /home/kazu/.julia/v0.6/Convex/src/expressions.jl:105.
# Use "const AbstractExprOrValue = Union{AbstractExpr,Value}" instead.
#
# WARNING: deprecated syntax "typealias Float64OrNothing Union{Float64,Void}" at /home/kazu/.julia/v0.6/Convex/src/problems.jl:7.
# Use "const Float64OrNothing = Union{Float64,Void}" instead.
#
# WARNING: deprecated syntax "function .+(...)".
# Use "function Base.broadcast(::typeof(+), ...)" instead.
#
# WARNING: deprecated syntax "function .+(...)".
# Use "function Base.broadcast(::typeof(+), ...)" instead.
#
# WARNING: deprecated syntax "function .+(...)".
# Use "function Base.broadcast(::typeof(+), ...)" instead.
#
# WARNING: deprecated syntax "function .-(...)".
# Use "function Base.broadcast(::typeof(-), ...)" instead.
#
# WARNING: deprecated syntax "function .-(...)".
# Use "function Base.broadcast(::typeof(-), ...)" instead.
#
# WARNING: deprecated syntax "function .-(...)".
# Use "function Base.broadcast(::typeof(-), ...)" instead.
#
# WARNING: deprecated syntax "function .*(...)".
# Use "function Base.broadcast(::typeof(*), ...)" instead.
#
# WARNING: deprecated syntax "function .*(...)".
# Use "function Base.broadcast(::typeof(*), ...)" instead.
#
# WARNING: deprecated syntax "function .*(...)".
# Use "function Base.broadcast(::typeof(*), ...)" instead.
#
# WARNING: deprecated syntax "function ./(...)".
# Use "function Base.broadcast(::typeof(/), ...)" instead.
#
# WARNING: deprecated syntax "typealias ArrayOrNothing Union{AbstractArray,Void}" at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/index.jl:5.
# Use "const ArrayOrNothing = Union{AbstractArray,Void}" instead.
#
# WARNING: deprecated syntax "function .^(...)".
# Use "function Base.broadcast(::typeof(^), ...)" instead.
#
# WARNING: deprecated syntax "function ./(...)".
# Use "function Base.broadcast(::typeof(/), ...)" instead.
# SCS.SCSSolver(Any[(:verbose, 0)])

# %% [markdown]
# Pick points

# %%
n_dims = 3

# Points
if n_dims==2
     x = [10 0;
          0 5;
          1 1]
elseif n_dims==3
     x = [10 0 0;
          0 10 0
          0 0 10;
          10 10 10]
else
     x = rand(n_dims+1, n_dims)
end
# Out:
# 4×3 Array{Int64,2}:
#  10   0   0
#   0  10   0
#   0   0  10
#  10  10  10

# %%
# Set up problem
A = Variable(n_dims,n_dims)
b = Variable(n_dims)

objective = logdet(A)

constraints = (norm(A*x[1,:]+b) <= 1)
for i in 2:size(x)[1]
     constraints += (norm(A*x[i,:]+b) <= 1)
end

problem = maximize(objective, constraints)
# Out:
# Problem:
# maximize AbstractExpr with
# head: logdet
# size: (1, 1)
# sign: Convex.NoSign()
# vexity: Convex.ConcaveVexity()
#
# subject to
# Constraint:
# <= constraint
# lhs: AbstractExpr with
# head: norm2
# size: (1, 1)
# sign: Convex.Positive()
# vexity: Convex.ConvexVexity()
#
# rhs: 1
# vexity: Convex.ConvexVexity()
# 		Constraint:
# <= constraint
# lhs: AbstractExpr with
# head: norm2
# size: (1, 1)
# sign: Convex.Positive()
# vexity: Convex.ConvexVexity()
#
# rhs: 1
# vexity: Convex.ConvexVexity()
# 		Constraint:
# <= constraint
# lhs: AbstractExpr with
# head: norm2
# size: (1, 1)
# sign: Convex.Positive()
# vexity: Convex.ConvexVexity()
#
# rhs: 1
# vexity: Convex.ConvexVexity()
# 		Constraint:
# <= constraint
# lhs: AbstractExpr with
# head: norm2
# size: (1, 1)
# sign: Convex.Positive()
# vexity: Convex.ConvexVexity()
#
# rhs: 1
# vexity: Convex.ConvexVexity()
# current status: not yet solved

# %%
solve!(problem)

# Results
println("Problem status: ", problem.status)
println("Optimal value: ", problem.optval)
println("A: ", A.value)
println("b: ", b.value)
A = A.value
b = b.value
# Out:
# WARNING: Array{T}(::Type{T}, m::Int) is deprecated, use Array{T}(m) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] Array(::Type{DataStructures.OrderedDict{UInt64,Tuple{Union{AbstractArray, Number},Union{AbstractArray, Number}}}}, ::Int64) at ./deprecated.jl:57
#  [3] conic_form!(::Convex.ExpConstraint, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/constraints/exp_constraints.jl:52
#  [4] conic_form!(::Convex.LogAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/exp_cone/log.jl:55
#  [5] conic_form!(::Convex.SumAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/sum.jl:48
#  [6] conic_form!(::Convex.LogDetAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/exp_+_sdp_cone/logdet.jl:38
#  [7] conic_form!(::Convex.AdditionAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/add_subtract.jl:108
#  [8] conic_form!(::Convex.EqConstraint, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/constraints/constraints.jl:43
#  [9] conic_form!(::Convex.Problem, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/problems.jl:99
#  [10] conic_problem(::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/problems.jl:124
#  [11] #solve!#25(::Bool, ::Bool, ::Bool, ::Function, ::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/solution.jl:25
#  [12] solve!(::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/solution.jl:21
#  [13] include_string(::String, ::String) at ./loading.jl:515
#  [14] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/kazu/.julia/v0.6/IJulia/src/execute_request.jl:160
#  [15] eventloop(::ZMQ.Socket) at /home/kazu/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [16] (::IJulia.##11#14)() at ./task.jl:335
# while loading In[15], in expression starting on line 1
# WARNING: Array{T}(::Type{T}, m::Int) is deprecated, use Array{T}(m) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64) at ./deprecated.jl:57
#  [3] conic_form!(::Convex.SDPConstraint, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/constraints/sdp_constraints.jl:52
#  [4] conic_form!(::Convex.LogDetAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/exp_+_sdp_cone/logdet.jl:56
#  [5] conic_form!(::Convex.AdditionAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/add_subtract.jl:108
#  [6] conic_form!(::Convex.EqConstraint, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/constraints/constraints.jl:43
#  [7] conic_form!(::Convex.Problem, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/problems.jl:99
#  [8] conic_problem(::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/problems.jl:124
#  [9] #solve!#25(::Bool, ::Bool, ::Bool, ::Function, ::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/solution.jl:25
#  [10] solve!(::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/solution.jl:21
#  [11] include_string(::String, ::String) at ./loading.jl:515
#  [12] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/kazu/.julia/v0.6/IJulia/src/execute_request.jl:160
#  [13] eventloop(::ZMQ.Socket) at /home/kazu/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [14] (::IJulia.##11#14)() at ./task.jl:335
# while loading In[15], in expression starting on line 1
# WARNING: Array{T}(::Type{T}, m::Int) is deprecated, use Array{T}(m) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64) at ./deprecated.jl:57
#  [3] conic_form!(::Convex.SDPConstraint, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/constraints/sdp_constraints.jl:53
#  [4] conic_form!(::Convex.LogDetAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/exp_+_sdp_cone/logdet.jl:56
#  [5] conic_form!(::Convex.AdditionAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/add_subtract.jl:108
#  [6] conic_form!(::Convex.EqConstraint, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/constraints/constraints.jl:43
#  [7] conic_form!(::Convex.Problem, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/problems.jl:99
#  [8] conic_problem(::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/problems.jl:124
#  [9] #solve!#25(::Bool, ::Bool, ::Bool, ::Function, ::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/solution.jl:25
#  [10] solve!(::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/solution.jl:21
#  [11] include_string(::String, ::String) at ./loading.jl:515
#  [12] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/kazu/.julia/v0.6/IJulia/src/execute_request.jl:160
#  [13] eventloop(::ZMQ.Socket) at /home/kazu/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [14] (::IJulia.##11#14)() at ./task.jl:335
# while loading In[15], in expression starting on line 1
# WARNING: Array{T}(::Type{T}, m::Int) is deprecated, use Array{T}(m) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64) at ./deprecated.jl:57
#  [3] conic_form!(::Convex.TransposeAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/transpose.jl:51
#  [4] conic_form!(::Convex.HcatAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/stack.jl:47
#  [5] conic_form!(::Convex.TransposeAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/transpose.jl:44
#  [6] conic_form!(::Convex.DotMultiplyAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/multiply_divide.jl:175
#  [7] conic_form!(::Convex.IndexAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/index.jl:72
#  [8] conic_form!(::Convex.SDPConstraint, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/constraints/sdp_constraints.jl:65
#  [9] conic_form!(::Convex.LogDetAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/exp_+_sdp_cone/logdet.jl:57
#  [10] conic_form!(::Convex.AdditionAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/add_subtract.jl:108
#  [11] conic_form!(::Convex.EqConstraint, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/constraints/constraints.jl:43
#  [12] conic_form!(::Convex.Problem, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/problems.jl:99
#  [13] conic_problem(::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/problems.jl:124
#  [14] #solve!#25(::Bool, ::Bool, ::Bool, ::Function, ::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/solution.jl:25
#  [15] solve!(::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/solution.jl:21
#  [16] include_string(::String, ::String) at ./loading.jl:515
#  [17] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/kazu/.julia/v0.6/IJulia/src/execute_request.jl:160
#  [18] eventloop(::ZMQ.Socket) at /home/kazu/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [19] (::IJulia.##11#14)() at ./task.jl:335
# while loading In[15], in expression starting on line 1
# WARNING: Array{T}(::Type{T}, m::Int) is deprecated, use Array{T}(m) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64) at ./deprecated.jl:57
#  [3] conic_form!(::Convex.TransposeAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/transpose.jl:52
#  [4] conic_form!(::Convex.HcatAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/stack.jl:47
#  [5] conic_form!(::Convex.TransposeAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/transpose.jl:44
#  [6] conic_form!(::Convex.DotMultiplyAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/multiply_divide.jl:175
#  [7] conic_form!(::Convex.IndexAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/index.jl:72
#  [8] conic_form!(::Convex.SDPConstraint, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/constraints/sdp_constraints.jl:65
#  [9] conic_form!(::Convex.LogDetAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/exp_+_sdp_cone/logdet.jl:57
#  [10] conic_form!(::Convex.AdditionAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/add_subtract.jl:108
#  [11] conic_form!(::Convex.EqConstraint, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/constraints/constraints.jl:43
#  [12] conic_form!(::Convex.Problem, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/problems.jl:99
#  [13] conic_problem(::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/problems.jl:124
#  [14] #solve!#25(::Bool, ::Bool, ::Bool, ::Function, ::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/solution.jl:25
#  [15] solve!(::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/solution.jl:21
#  [16] include_string(::String, ::String) at ./loading.jl:515
#  [17] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/kazu/.julia/v0.6/IJulia/src/execute_request.jl:160
#  [18] eventloop(::ZMQ.Socket) at /home/kazu/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [19] (::IJulia.##11#14)() at ./task.jl:335
# while loading In[15], in expression starting on line 1
# WARNING: Array{T}(::Type{T}, m::Int) is deprecated, use Array{T}(m) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64) at ./deprecated.jl:57
#  [3] conic_form!(::Convex.CTransposeAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/transpose.jl:114
#  [4] conic_form!(::Convex.HcatAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/stack.jl:47
#  [5] conic_form!(::Convex.TransposeAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/transpose.jl:44
#  [6] conic_form!(::Convex.HcatAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/stack.jl:47
#  [7] conic_form!(::Convex.TransposeAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/transpose.jl:44
#  [8] conic_form!(::Convex.DotMultiplyAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/multiply_divide.jl:175
#  [9] conic_form!(::Convex.IndexAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/index.jl:72
#  [10] conic_form!(::Convex.SDPConstraint, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/constraints/sdp_constraints.jl:65
#  [11] conic_form!(::Convex.LogDetAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/exp_+_sdp_cone/logdet.jl:57
#  [12] conic_form!(::Convex.AdditionAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/add_subtract.jl:108
#  [13] conic_form!(::Convex.EqConstraint, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/constraints/constraints.jl:43
#  [14] conic_form!(::Convex.Problem, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/problems.jl:99
#  [15] conic_problem(::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/problems.jl:124
#  [16] #solve!#25(::Bool, ::Bool, ::Bool, ::Function, ::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/solution.jl:25
#  [17] solve!(::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/solution.jl:21
#  [18] include_string(::String, ::String) at ./loading.jl:515
#  [19] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/kazu/.julia/v0.6/IJulia/src/execute_request.jl:160
#  [20] eventloop(::ZMQ.Socket) at /home/kazu/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [21] (::IJulia.##11#14)() at ./task.jl:335
# while loading In[15], in expression starting on line 1
# WARNING: Array{T}(::Type{T}, m::Int) is deprecated, use Array{T}(m) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at
# Problem status: Optimal
# Optimal value: -6.475379847441721
# A: [0.115464 -5.53249e-6 -5.29207e-6; -2.51302e-6 0.115471 -5.17451e-6; -2.40268e-6 -2.38594e-6 0.115477]
# b: [-0.577166; -0.577212; -0.577252]
# ./deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64) at ./deprecated.jl:57
#  [3] conic_form!(::Convex.CTransposeAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/transpose.jl:115
#  [4] conic_form!(::Convex.HcatAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/stack.jl:47
#  [5] conic_form!(::Convex.TransposeAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/transpose.jl:44
#  [6] conic_form!(::Convex.HcatAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/stack.jl:47
#  [7] conic_form!(::Convex.TransposeAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/transpose.jl:44
#  [8] conic_form!(::Convex.DotMultiplyAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/multiply_divide.jl:175
#  [9] conic_form!(::Convex.IndexAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/index.jl:72
#  [10] conic_form!(::Convex.SDPConstraint, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/constraints/sdp_constraints.jl:65
#  [11] conic_form!(::Convex.LogDetAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/exp_+_sdp_cone/logdet.jl:57
#  [12] conic_form!(::Convex.AdditionAtom, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/atoms/affine/add_subtract.jl:108
#  [13] conic_form!(::Convex.EqConstraint, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/constraints/constraints.jl:43
#  [14] conic_form!(::Convex.Problem, ::Convex.UniqueConicForms) at /home/kazu/.julia/v0.6/Convex/src/problems.jl:99
#  [15] conic_problem(::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/problems.jl:124
#  [16] #solve!#25(::Bool, ::Bool, ::Bool, ::Function, ::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/solution.jl:25
#  [17] solve!(::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/solution.jl:21
#  [18] include_string(::String, ::String) at ./loading.jl:515
#  [19] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/kazu/.julia/v0.6/IJulia/src/execute_request.jl:160
#  [20] eventloop(::ZMQ.Socket) at /home/kazu/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [21] (::IJulia.##11#14)() at ./task.jl:335
# while loading In[15], in expression starting on line 1
# WARNING: isnan{T <: Number}(x::AbstractArray{T}) is deprecated, use isnan.(x) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] isnan(::Array{Float64,1}) at ./deprecated.jl:57
#  [3] populate_solution!(::SCS.SCSMathProgModel, ::Convex.Problem, ::Dict{UInt64,Tuple{Int64,Int64}}, ::Array{Convex.ConicConstr,1}) at /home/kazu/.julia/v0.6/Convex/src/solution.jl:118
#  [4] #solve!#25(::Bool, ::Bool, ::Bool, ::Function, ::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/solution.jl:38
#  [5] solve!(::Convex.Problem) at /home/kazu/.julia/v0.6/Convex/src/solution.jl:21
#  [6] include_string(::String, ::String) at ./loading.jl:515
#  [7] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/kazu/.julia/v0.6/IJulia/src/execute_request.jl:160
#  [8] eventloop(::ZMQ.Socket) at /home/kazu/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [9] (::IJulia.##11#14)() at ./task.jl:335
# while loading In[15], in expression starting on line 1
# 3×1 Array{Float64,2}:
#  -0.577166
#  -0.577212
#  -0.577252

# %%
# Plot

angles = collect(0 : 0.1 : 2*pi)
if n_dims==2
     vecs = [cos.(angles)-b[1] sin.(angles)-b[2]]'
     ellipse = inv(A) * vecs

     for i in 1:size(x)[1]
          plot(x[i,1], x[i,2], "ro")
     end

     plot(ellipse[1,:], ellipse[2,:], "b.")
     axis("equal")
elseif n_dims==3
     vecs = []
     for i in angles
          for j in angles
               v = [cos.(i).*sin.(j)-b[1] sin.(i).*sin.(j)-b[2] cos.(j)-b[3]]
               if isempty(vecs)
                    vecs = v
               end
               vecs = [vecs; v]
          end
     end

     for i in 1:size(x)[1]
          plot3D([x[i,1]], [x[i,2]], [x[i,3]], "ro")
     end

     ellipse = inv(A)*vecs'
     plot3D(ellipse[1,:], ellipse[2,:], ellipse[3,:], "b.", markersize=1)
     axis("equal")
end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f77d1a931d0>)
# (-4.0, 14.0, -4.0, 14.0)
